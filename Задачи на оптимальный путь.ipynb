# %% [markdown]
# # Макаров Сергей Иванович
# ## Задача 1

# %% [markdown]
# ![Задача 1](./картинки/Задача%201%20(готова).png)

# %% [markdown]
# Обозначим К поясом все точки, которые лежат на расстоянии k шагов от конечного пункта
# 1. 7 8 9
# 2. 5 6
# 3. 2 3 4
# 4. 1
#
# S (переменная состояния) равна номеру пункта, в котором находится процесс. (номер предыдущего пояса)
# J (переменная управления) - пункт, в который переходит процесс в поясе k-1. (следующего пояса)

# %% [markdown]
# ## Задача 2
# ![Задача 2](./картинки/Задача%202.jpg)

# %% [markdown]
# ## Задача 3
# ![Задача 3](./картинки/Задача%203.jpg)
